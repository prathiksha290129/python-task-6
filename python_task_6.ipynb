# %%
import pandas as pd

# %%
df=pd.read_csv("financial_dataset.csv")

# %%
df
# Out:
#       Transaction_ID Customer_ID Customer_Name     Category    Sales  Profit  \
# 0              11317    CUST1134        Anjali    Furniture   1875.0  4126.0
# 1              11001    CUST1177         Sneha   Stationery  32521.0  9290.0
# 2              11069    CUST1478         Sneha         food   8948.0  8683.0
# 3              11968    CUST1016         Priya    Furniture  20072.0  8320.0
# 4              10530    CUST1321         Priya   Stationery  32943.0  9336.0
# ...              ...         ...           ...          ...      ...     ...
# 1995           10700    CUST1427         Rahul  Electronics  14407.0  9016.0
# 1996           11500    CUST1136          Neha  Electronics   2105.0  5292.0
# 1997           11706    CUST1247         Vivek         Food  35927.0  2756.0
# 1998           10511    CUST1299         Rahul    Furniture  48447.0  1654.0
# 1999           11083    CUST1075          Arun     Clothing   8433.0  4718.0
#
#       Quantity Payment_Status       City  Transaction_Date
# 0           16        Pending     Mumbai   10/21/2026 0:00
# 1           13           Paid  Bangalore    5/16/2026 0:00
# 2            3         Unpaid    Chennai    6/19/2026 0:00
# 3            1        Pending     Mumbai   9/11/2027 12:00
# 4            3           Paid  Bangalore   9/22/2025 12:00
# ...        ...            ...        ...               ...
# 1995         8           paid  Bangalore  12/16/2025 12:00
# 1996        13         Unpaid      Delhi   1/20/2027 12:00
# 1997         5        Pending  Mangalore    5/3/2027 12:00
# 1998         7         Unpaid      Delhi    9/13/2025 0:00
# 1999         5        Pending      Kochi    6/26/2026 0:00
#
# [2000 rows x 10 columns]

# %%
df.head()
# Out:
#    Transaction_ID Customer_ID Customer_Name    Category    Sales  Profit  \
# 0           11317    CUST1134        Anjali   Furniture   1875.0  4126.0
# 1           11001    CUST1177         Sneha  Stationery  32521.0  9290.0
# 2           11069    CUST1478         Sneha        food   8948.0  8683.0
# 3           11968    CUST1016         Priya   Furniture  20072.0  8320.0
# 4           10530    CUST1321         Priya  Stationery  32943.0  9336.0
#
#    Quantity Payment_Status       City Transaction_Date
# 0        16        Pending     Mumbai  10/21/2026 0:00
# 1        13           Paid  Bangalore   5/16/2026 0:00
# 2         3         Unpaid    Chennai   6/19/2026 0:00
# 3         1        Pending     Mumbai  9/11/2027 12:00
# 4         3           Paid  Bangalore  9/22/2025 12:00

# %%
df.isnull().sum()
# Out:
# Transaction_ID       0
# Customer_ID          0
# Customer_Name        0
# Category            23
# Sales               33
# Profit              30
# Quantity             0
# Payment_Status       0
# City                21
# Transaction_Date     0
# dtype: int64

# %%
df["Sales"]=df["Sales"].fillna(df["Sales"].mean())

# %%
df["Category"]=df["Category"].fillna(df["Category"].mode()[0])

# %%
df["City"]=df["City"].fillna(df["City"].mode()[0])

# %%
df["Profit"]=df["Profit"].fillna(df["Profit"].mean())

# %%
df.duplicated().sum()
# Out:
# np.int64(40)

# %%
df=df.drop_duplicates()

# %%
df["Category"]=df["Category"].str.strip().str.title()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_8628\3960893055.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Category"]=df["Category"].str.strip().str.title()

# %%
df["Payment_Status"]=df["Payment_Status"].str.strip().str.title()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_8628\1034170163.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Payment_Status"]=df["Payment_Status"].str.strip().str.title()

# %%
df["City"]=df["City"].str.strip().str.title()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_8628\3137970100.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["City"]=df["City"].str.strip().str.title()

# %%
df["Transaction_Date"] = pd.to_datetime(df["Transaction_Date"],errors="coarce")
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df["Transaction_Date"]=pd.to_datetime(df["Transaction_Date"],errors="coarca")
#       2 df.dtypes
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1072, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1070         result = arg.map(cache_array)
#    1071     else:
# -> 1072         values = convert_listlike(arg._values, format)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     434 if format is not None and format != "mixed":
# --> 435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#    (...)    443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:469, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     458 def _array_strptime_with_fallback(
#     459     arg,
#     460     name,
#    (...)    464     errors: str,
#     465 ) -> Index:
#     466     """
#     467     Call array_strptime, with fallback behavior depending on 'errors'.
#     468     """
# --> 469     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     470     if tz_out is not None:
#     471         unit = np.datetime_data(result.dtype)[0]
#
# File pandas/_libs/tslibs/strptime.pyx:337, in pandas._libs.tslibs.strptime.array_strptime()
#
# AssertionError:
